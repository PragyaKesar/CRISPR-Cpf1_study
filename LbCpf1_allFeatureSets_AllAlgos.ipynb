# %% [markdown]
# # Sequence Associated Features

# %% [markdown]
# # AdaBoostClassifier

# %%
import warnings  
import pandas as pd
import numpy as np
np.random.seed(198)
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sys import *
OT_data=pd.read_csv("D://PhD_related/Dataset/LbCpf1_dataset_features_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
features = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[features]
target = OT_data['Y']
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.25, shuffle=True)

ada= AdaBoostClassifier(n_estimators=118, learning_rate=0.641, random_state=0)
ada.fit(data_train, target_train)

Pred_labels = ada.predict(data_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels.round()))
print(classification_report(target_test,Pred_labels.round()))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels.round()))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels.round())
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels.round())
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
rms= sqrt(mean_squared_error(target_test,Pred_labels.round()))
print(rms)
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round()))
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [0 1]
# [[20068    10]
#  [   39    90]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20078
#            1       0.90      0.70      0.79       129
#
#     accuracy                           1.00     20207
#    macro avg       0.95      0.85      0.89     20207
# weighted avg       1.00      1.00      1.00     20207
#
# 0.7848265050244447
# No Skill PR AUC: 0.800
# Logistic ROC AUC 0.849
# SpearmanrResult(correlation=0.7912688958941917, pvalue=0.0)
# 0.0024249022615925177
# 0.0024249022615925177
# 0.04924329661580871
# 0.6177145566399568
# 0.6180392592918623
# 0.7912688958941917

# %% [markdown]
# # LinearSVC

# %%
import warnings  
import pandas as pd
import numpy as np
np.random.seed(198)
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sys import *
OT_data=pd.read_csv("D://PhD_related/Dataset/LbCpf1_dataset_features_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
features = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[features]
target = OT_data['Y']
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.25, shuffle=True)

svc=LinearSVC(C=2, loss='squared_hinge', penalty='l2', dual=False, tol=0.0002, class_weight={0:0.122, 1:0.50})
svc.fit(data_train, target_train)

Pred_labels = svc.predict(data_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels.round()))
print(classification_report(target_test,Pred_labels.round()))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels.round()))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels.round())
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels.round())
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
rms= sqrt(mean_squared_error(target_test,Pred_labels.round()))
print(rms)
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round()))
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [0 1]
# [[20038    40]
#  [   19   110]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20078
#            1       0.73      0.85      0.79       129
#
#     accuracy                           1.00     20207
#    macro avg       0.87      0.93      0.89     20207
# weighted avg       1.00      1.00      1.00     20207
#
# 0.787068813243954
# No Skill PR AUC: 0.793
# Logistic ROC AUC 0.925
# SpearmanrResult(correlation=0.7893390528844778, pvalue=0.0)
# 0.0029197802741624188
# 0.0029197802741624188
# 0.054034991201650236
# 0.5396971192195398
# 0.5398673854139396
# 0.7893390528844779

# %% [markdown]
# # MLPCLassifier

# %%
import warnings  
import pandas as pd
import numpy as np
np.random.seed(198)
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from sys import *
OT_data=pd.read_csv("D://PhD_related/Dataset/LbCpf1_dataset_features_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
features = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[features]
target = OT_data['Y']
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.25, shuffle=True)
mlp= MLPClassifier(solver='adam', alpha=0.0002, activation= 'relu', hidden_layer_sizes=[20,28,12,10,14,5], learning_rate_init=0.001, random_state=6, tol=0.00002, learning_rate='adaptive', beta_1=0.9, beta_2=0.71, epsilon=1e-24, n_iter_no_change=20, validation_fraction=0.25, verbose=True)
mlp.fit(data_train, target_train)

Pred_labels = mlp.predict(data_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels.round()))
print(classification_report(target_test,Pred_labels.round()))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels.round()))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels.round())
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels.round())
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
rms= sqrt(mean_squared_error(target_test,Pred_labels.round()))
print(rms)
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round()))
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [0 1]
# Iteration 1, loss = 0.29773447
# Iteration 2, loss = 0.02324010
# Iteration 3, loss = 0.01813579
# Iteration 4, loss = 0.01412279
# Iteration 5, loss = 0.01178855
# Iteration 6, loss = 0.01121262
# Iteration 7, loss = 0.01040835
# Iteration 8, loss = 0.01047980
# Iteration 9, loss = 0.00970622
# Iteration 10, loss = 0.00974306
# Iteration 11, loss = 0.00961077
# Iteration 12, loss = 0.00956997
# Iteration 13, loss = 0.00983505
# Iteration 14, loss = 0.00921750
# Iteration 15, loss = 0.00945404
# Iteration 16, loss = 0.01045548
# Iteration 17, loss = 0.00967594
# Iteration 18, loss = 0.00947036
# Iteration 19, loss = 0.00911089
# Iteration 20, loss = 0.00932054
# Iteration 21, loss = 0.00950500
# Iteration 22, loss = 0.00933700
# Iteration 23, loss = 0.00929816
# Iteration 24, loss = 0.00954958
# Iteration 25, loss = 0.00905613
# Iteration 26, loss = 0.00941422
# Iteration 27, loss = 0.00946568
# Iteration 28, loss = 0.00946611
# Iteration 29, loss = 0.00927137
# Iteration 30, loss = 0.00916649
# Iteration 31, loss = 0.00907821
# Iteration 32, loss = 0.00913454
# Iteration 33, loss = 0.00911102
# Iteration 34, loss = 0.00908726
# Iteration 35, loss = 0.00938164
# Iteration 36, loss = 0.00890265
# Iteration 37, loss = 0.00901123
# Iteration 38, loss = 0.00870459
# Iteration 39, loss = 0.00906789
# Iteration 40, loss = 0.00868743
# Iteration 41, loss = 0.00869672
# Iteration 42, loss = 0.00879550
# Iteration 43, loss = 0.00928050
# Iteration 44, loss = 0.00871577
# Iteration 45, loss = 0.00901443
# Iteration 46, loss = 0.00993371
# Iteration 47, loss = 0.00932292
# Iteration 48, loss = 0.00900317
# Iteration 49, loss = 0.00926099
# Iteration 50, loss = 0.00939379
# Iteration 51, loss = 0.00953510
# Iteration 52, loss = 0.00947613
# Iteration 53, loss = 0.00953665
# Iteration 54, loss = 0.00957377
# Iteration 55, loss = 0.01051458
# Iteration 56, loss = 0.00949784
# Iteration 57, loss = 0.00891850
# Iteration 58, loss = 0.00893356
# Iteration 59, loss = 0.00908770
# Training loss did not improve more than tol=0.000020 for 20 consecutive epochs. Stopping.
# [[20059    19]
#  [   25   104]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20078
#            1       0.85      0.81      0.83       129
#
#     accuracy                           1.00     20207
#    macro avg       0.92      0.90      0.91     20207
# weighted avg       1.00      1.00      1.00     20207
#
# 0.8243018873890163
# No Skill PR AUC: 0.826
# Logistic ROC AUC 0.903
# SpearmanrResult(correlation=0.8245385745280808, pvalue=0.0)
# 0.002177463255307567
# 0.002177463255307567
# 0.04666329666137581
# 0.6567232753501653
# 0.6567371746313407
# 0.8245385745280809

# %%
import shap
data_for_prediction = shap.sample(data_test, 200)
#data_for_prediction = data_test.iloc[row_to_show]  # use 1 row of data here. Could use multiple rows if desired
#data_for_prediction.head()
#data_for_prediction_array = data_for_prediction.values.reshape(1, -1)
#n1=model.predict_proba(data_for_prediction_array)
#n1=model1.predict_proba(data_for_prediction)
data_for_prediction1 = shap.sample(data_train, 200)
#data_for_prediction=np.asarray(data_for_prediction)
#data_for_prediction1=np.asarray(data_for_prediction1)
#explainer1 = shap.Explainer(model1.predict_proba, data_test)
#shap_values = explainer1(data_train)
k_explainer = shap.KernelExplainer(mlp.predict_proba, data_for_prediction)
k_shap_values = k_explainer.shap_values(data_for_prediction1, l1_reg="num_features(600)")

#explainer = shap.Explainer(model, data_train.loc[:50,:], feature_names=data_train.columns)
#shap_values = explainer(data_test.loc[:50,:])
# Out:
# Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
shap.summary_plot(k_shap_values[0], data_for_prediction, max_display=20)

# %% [markdown]
# # DecisionTreeClassifier

# %%
import warnings  
import pandas as pd
import numpy as np
np.random.seed(198)
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sys import *
OT_data=pd.read_csv("D://PhD_related/Dataset/LbCpf1_dataset_features_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
features = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[features]
target = OT_data['Y']
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.25, shuffle=True)

dtc= DecisionTreeClassifier(class_weight={0:0.25, 1:1},max_features=239, max_depth=1000, ccp_alpha=1e-10, random_state=0)
dtc.fit(data_train, target_train)

Pred_labels = dtc.predict(data_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels.round()))
print(classification_report(target_test,Pred_labels.round()))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels.round()))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels.round())
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels.round())
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
rms= sqrt(mean_squared_error(target_test,Pred_labels.round()))
print(rms)
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round()))
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [0 1]
# [[20038    40]
#  [   26   103]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20078
#            1       0.72      0.80      0.76       129
#
#     accuracy                           1.00     20207
#    macro avg       0.86      0.90      0.88     20207
# weighted avg       1.00      1.00      1.00     20207
#
# 0.7557131631440027
# No Skill PR AUC: 0.760
# Logistic ROC AUC 0.898
# SpearmanrResult(correlation=0.756729812080893, pvalue=0.0)
# 0.00326619488296135
# 0.00326619488296135
# 0.05715063326824428
# 0.4850849130252479
# 0.48516058688942565
# 0.7567298120808928

# %% [markdown]
# # LogisticRegression

# %%
import warnings  
import pandas as pd
import numpy as np
np.random.seed(198)
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sys import *
OT_data=pd.read_csv("D://PhD_related/Dataset/LbCpf1_dataset_features_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
features = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[features]
target = OT_data['Y']
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.25, shuffle=True)

lg1=LogisticRegression(class_weight={0:0.5, 1:2}, C=1, max_iter=300, solver='newton-cg')
lg1.fit(data_train, target_train)

Pred_labels = lg1.predict(data_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels.round()))
print(classification_report(target_test,Pred_labels.round()))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels.round()))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels.round())
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels.round())
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
rms= sqrt(mean_squared_error(target_test,Pred_labels.round()))
print(rms)
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round()))
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [0 1]
# [[20042    36]
#  [   19   110]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20078
#            1       0.75      0.85      0.80       129
#
#     accuracy                           1.00     20207
#    macro avg       0.88      0.93      0.90     20207
# weighted avg       1.00      1.00      1.00     20207
#
# 0.7986350336648574
# No Skill PR AUC: 0.804
# Logistic ROC AUC 0.925
# SpearmanrResult(correlation=0.8001864297297379, pvalue=0.0)
# 0.0027218290691344584
# 0.0027218290691344584
# 0.05217115169453765
# 0.5709040941877066
# 0.5710156745282544
# 0.800186429729738

# %% [markdown]
# # Mismatch energy associated features

# %% [markdown]
# # AdaBoostClassifier

# %%
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,LogisticRegression
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(255)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
target = OT_data['Y']
#fs_selector = VarianceThreshold(0.000019)
#data=sfs.transform(data)
#data = fs_selector.fit_transform(data, target)
data_train1, data_test1, target_train1, target_test1 = train_test_split(data,target, test_size = 0.25, shuffle=True)
class_names=np.array(['0','1'])
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(n_estimators=503, learning_rate= 0.98)
#n_e=27, lr0.98
clf.fit(data_train1, target_train1)
Pred_labels = clf.predict(data_test1)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test1,Pred_labels.round()))
print(classification_report(target_test1,Pred_labels.round()))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test1,Pred_labels.round()))
precision, recall, _ = precision_recall_curve(target_test1,Pred_labels.round())
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test1,Pred_labels.round())
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test1,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test1,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test1,Pred_labels.round()))
from math import sqrt
rms= sqrt(mean_squared_error(target_test1,Pred_labels.round()))
print(rms)
from sklearn.metrics import r2_score
print(r2_score(target_test1,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test1,Pred_labels.round()))
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test1,Pred_labels.round()))
# Out:
# off-target' :  [0 1]
# [[20056    16]
#  [   28   111]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20072
#            1       0.87      0.80      0.83       139
#
#     accuracy                           1.00     20211
#    macro avg       0.94      0.90      0.92     20211
# weighted avg       1.00      1.00      1.00     20211
#
# 0.8334929842233965
# No Skill PR AUC: 0.837
# Logistic ROC AUC 0.899
# SpearmanrResult(correlation=0.8343537133321683, pvalue=0.0)
# 0.0021770323091385877
# 0.0021770323091385877
# 0.04665867881904274
# 0.6812611290003471
# 0.6813127417555793
# 0.8343537133321683

# %%
import shap
data_for_prediction = shap.sample(data_test, 200)
#data_for_prediction = data_test.iloc[row_to_show]  # use 1 row of data here. Could use multiple rows if desired
#data_for_prediction.head()
#data_for_prediction_array = data_for_prediction.values.reshape(1, -1)
#n1=model.predict_proba(data_for_prediction_array)
#n1=model1.predict_proba(data_for_prediction)
data_for_prediction1 = shap.sample(data_train, 200)
#data_for_prediction=np.asarray(data_for_prediction)
#data_for_prediction1=np.asarray(data_for_prediction1)
#explainer1 = shap.Explainer(model1.predict_proba, data_test)
#shap_values = explainer1(data_train)
k_explainer = shap.KernelExplainer(clf.predict_proba, data_for_prediction)
k_shap_values = k_explainer.shap_values(data_for_prediction1, l1_reg="num_features(600)")

#explainer = shap.Explainer(model, data_train.loc[:50,:], feature_names=data_train.columns)
#shap_values = explainer(data_test.loc[:50,:])
# Out:
# Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
shap.summary_plot(k_shap_values[0], data_for_prediction, max_display=20)

# %% [markdown]
# # LnearSVC

# %%
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,LogisticRegression
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
import numpy as np
np.random.seed(255)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
target = OT_data['Y']
#fs_selector = VarianceThreshold(0.000019)
#data=sfs.transform(data)
#data = fs_selector.fit_transform(data, target)
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.25, shuffle=True)
class_names=np.array(['0','1'])
from sklearn.ensemble import AdaBoostClassifier
svc=LinearSVC(C=2, loss='squared_hinge', penalty='l2', dual=False, tol=0.0002, class_weight={0:0.122, 1:0.50})
svc.fit(data_train, target_train)
Pred_labels = svc.predict(data_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels.round()))
print(classification_report(target_test,Pred_labels.round()))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels.round()))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels.round())
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels.round())
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
rms= sqrt(mean_squared_error(target_test,Pred_labels.round()))
print(rms)
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round()))
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [0 1]
# [[20066     6]
#  [   40    99]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20072
#            1       0.94      0.71      0.81       139
#
#     accuracy                           1.00     20211
#    macro avg       0.97      0.86      0.91     20211
# weighted avg       1.00      1.00      1.00     20211
#
# 0.8103528674534819
# No Skill PR AUC: 0.829
# Logistic ROC AUC 0.856
# SpearmanrResult(correlation=0.8184333497261822, pvalue=0.0)
# 0.0022759883231903417
# 0.0022759883231903417
# 0.04770731938801783
# 0.6667729985003629
# 0.6671873342298662
# 0.8184333497261823

# %% [markdown]
# # Decision tree Classifier

# %%
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(255)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
target = OT_data['Y']
#fs_selector = VarianceThreshold(0.000019)
#data=sfs.transform(data)
#data = fs_selector.fit_transform(data, target)
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.25, shuffle=True)
class_names=np.array(['0','1'])

dtc= DecisionTreeClassifier(class_weight={0:0.25, 1:1},max_features=20, max_depth=10, ccp_alpha=1e-10, random_state=0)
dtc.fit(data_train, target_train)
Pred_labels = dtc.predict(data_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels.round()))
print(classification_report(target_test,Pred_labels.round()))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels.round()))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels.round())
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels.round())
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
rms= sqrt(mean_squared_error(target_test,Pred_labels.round()))
print(rms)
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round()))
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [0 1]
# [[20006    66]
#  [   26   113]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20072
#            1       0.63      0.81      0.71       139
#
#     accuracy                           1.00     20211
#    macro avg       0.81      0.90      0.85     20211
# weighted avg       1.00      1.00      1.00     20211
#
# 0.7084343682064109
# No Skill PR AUC: 0.723
# Logistic ROC AUC 0.905
# SpearmanrResult(correlation=0.7141961912309789, pvalue=0.0)
# 0.0045519766463806835
# 0.0045519766463806835
# 0.06746833810299972
# 0.33354599700072574
# 0.3341194720588617
# 0.714196191230979

# %% [markdown]
# # MLPClassifier

# %%
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,LogisticRegression
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(255)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
target = OT_data['Y']
#fs_selector = VarianceThreshold(0.000019)
#data=sfs.transform(data)
#data = fs_selector.fit_transform(data, target)
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.25, shuffle=True)
class_names=np.array(['0','1'])
from sklearn.ensemble import AdaBoostClassifier
clf = MLPClassifier(solver='adam', alpha=0.0002, activation= 'relu', hidden_layer_sizes=[10, 10, 10, 17, 12], learning_rate_init=0.001, random_state=13, tol=0.2, learning_rate='adaptive', beta_1=0.9, beta_2=0.71, epsilon=1e-23, n_iter_no_change=20, validation_fraction=0.25, verbose=False)
#n_e=27, lr0.98
clf.fit(data_train, target_train)
Pred_labels = clf.predict(data_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels.round()))
print(classification_report(target_test,Pred_labels.round()))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels.round()))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels.round())
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels.round())
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
rms= sqrt(mean_squared_error(target_test,Pred_labels.round()))
print(rms)
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round()))
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [0 1]
# [[20063     9]
#  [   38   101]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20072
#            1       0.92      0.73      0.81       139
#
#     accuracy                           1.00     20211
#    macro avg       0.96      0.86      0.91     20211
# weighted avg       1.00      1.00      1.00     20211
#
# 0.8100910063437146
# No Skill PR AUC: 0.823
# Logistic ROC AUC 0.863
# SpearmanrResult(correlation=0.8157104835685665, pvalue=0.0)
# 0.002325466330216219
# 0.002325466330216219
# 0.048223089181596596
# 0.6595289332503708
# 0.6598303660778035
# 0.8157104835685666

# %% [markdown]
# # Logistic Regression

# %%
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,LogisticRegression
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(255)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
target = OT_data['Y']
#fs_selector = VarianceThreshold(0.000019)
#data=sfs.transform(data)
#data = fs_selector.fit_transform(data, target)
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.25, shuffle=True)
class_names=np.array(['0','1'])
from sklearn.ensemble import AdaBoostClassifier
lg1=LogisticRegression(class_weight={0:0.5, 1:2}, C=1, max_iter=300, solver='newton-cg')
lg1.fit(data_train, target_train)
Pred_labels = lg1.predict(data_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels.round()))
print(classification_report(target_test,Pred_labels.round()))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels.round()))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels.round())
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels.round())
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
rms= sqrt(mean_squared_error(target_test,Pred_labels.round()))
print(rms)
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round()))
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [0 1]
# [[20055    17]
#  [   37   102]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20072
#            1       0.86      0.73      0.79       139
#
#     accuracy                           1.00     20211
#    macro avg       0.93      0.87      0.89     20211
# weighted avg       1.00      1.00      1.00     20211
#
# 0.7893613177708693
# No Skill PR AUC: 0.796
# Logistic ROC AUC 0.866
# SpearmanrResult(correlation=0.7917744578887825, pvalue=0.0)
# 0.0026718123793973577
# 0.0026718123793973577
# 0.051689577086656044
# 0.6088204765004259
# 0.6089638452649602
# 0.7917744578887825

# %% [markdown]
# # Sequence and mismatch energy associated features

# %% [markdown]
# # MLPClassifier

# %%
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,LogisticRegression
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(47)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset_MM-SeqComb_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
target = OT_data['Y']
#fs_selector = VarianceThreshold(0.000019)
#data=sfs.transform(data)
#data = fs_selector.fit_transform(data, target)
data_train2, data_test2, target_train2, target_test2 = train_test_split(data,target, test_size = 0.25, shuffle=True)
class_names=np.array(['0','1'])
from sklearn.ensemble import AdaBoostClassifier
from random import *
clf2 = MLPClassifier(solver='adam', alpha=0.0002, activation= 'relu', hidden_layer_sizes=[10, 10, 12, 25, 12], learning_rate_init=0.001, random_state=13, tol=0.0000002, learning_rate='adaptive', beta_1=0.9, beta_2=0.71, epsilon=1e-23, n_iter_no_change=20, validation_fraction=0.25, verbose=False)
clf2.fit(data_train2, target_train2)
Pred_labels = clf2.predict(data_test2)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test2,Pred_labels))
print(classification_report(target_test2,Pred_labels))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test2,Pred_labels))
precision, recall, _ = precision_recall_curve(target_test2,Pred_labels)
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test2,Pred_labels)
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test2,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test2,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test2,Pred_labels.round()))
from math import sqrt
print(sqrt(mean_squared_error(target_test2,Pred_labels.round())))
from sklearn.metrics import r2_score
print(r2_score(target_test2,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test2,Pred_labels.round())) 
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test2,Pred_labels.round()))
# Out:
# off-target' :  [1 0]
# [[20044    26]
#  [   23   114]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20070
#            1       0.81      0.83      0.82       137
#
#     accuracy                           1.00     20207
#    macro avg       0.91      0.92      0.91     20207
# weighted avg       1.00      1.00      1.00     20207
#
# 0.8218840186300398
# No Skill PR AUC: 0.824
# Logistic ROC AUC 0.915
# SpearmanrResult(correlation=0.8219328923507336, pvalue=0.0)
# 0.0024249022615925177
# 0.0024249022615925177
# 0.04924329661580871
# 0.6398943115155349
# 0.6398975847308143
# 0.8219328923507336

# %%
import shap
data_for_prediction = shap.sample(data_test, 200)
#data_for_prediction = data_test.iloc[row_to_show]  # use 1 row of data here. Could use multiple rows if desired
#data_for_prediction.head()
#data_for_prediction_array = data_for_prediction.values.reshape(1, -1)
#n1=model.predict_proba(data_for_prediction_array)
#n1=model1.predict_proba(data_for_prediction)
data_for_prediction1 = shap.sample(data_train, 200)
#data_for_prediction=np.asarray(data_for_prediction)
#data_for_prediction1=np.asarray(data_for_prediction1)
#explainer1 = shap.Explainer(model1.predict_proba, data_test)
#shap_values = explainer1(data_train)
k_explainer = shap.KernelExplainer(clf2.predict_proba, data_for_prediction)
k_shap_values = k_explainer.shap_values(data_for_prediction1, l1_reg="num_features(600)")

#explainer = shap.Explainer(model, data_train.loc[:50,:], feature_names=data_train.columns)
#shap_values = explainer(data_test.loc[:50,:])
# Out:
# Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
shap.summary_plot(k_shap_values[0], data_for_prediction, max_display=20)

# %% [markdown]
# # DecisionTreeClassifier

# %%
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,LogisticRegression
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import numpy as np
np.random.seed(47)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset_MM-SeqComb_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
target = OT_data['Y']
#fs_selector = VarianceThreshold(0.000019)
#data=sfs.transform(data)
#data = fs_selector.fit_transform(data, target)
data_train2, data_test2, target_train2, target_test2 = train_test_split(data,target, test_size = 0.25, shuffle=True)
class_names=np.array(['0','1'])
from sklearn.ensemble import AdaBoostClassifier
from random import *
dtc= DecisionTreeClassifier(class_weight={0:0.25, 1:1},max_features=240, max_depth=18, ccp_alpha=1e-10, random_state=0)
dtc.fit(data_train, target_train)
Pred_labels = dtc.predict(data_test)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels))
print(classification_report(target_test,Pred_labels))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels)
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels)
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
print(sqrt(mean_squared_error(target_test,Pred_labels.round())))
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round())) 
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [1 0]
# [[20033    37]
#  [   40    97]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20070
#            1       0.72      0.71      0.72       137
#
#     accuracy                           1.00     20207
#    macro avg       0.86      0.85      0.86     20207
# weighted avg       1.00      1.00      1.00     20207
#
# 0.7139492526815092
# No Skill PR AUC: 0.717
# Logistic ROC AUC 0.853
# SpearmanrResult(correlation=0.7139935956782119, pvalue=0.0)
# 0.003810560696788242
# 0.003810560696788242
# 0.06172973916021549
# 0.43411963238155493
# 0.4341229055968341
# 0.713993595678212

# %% [markdown]
# # LOgisticRegression

# %%
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,LogisticRegression
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(47)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset_MM-SeqComb_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
target = OT_data['Y']
#fs_selector = VarianceThreshold(0.000019)
#data=sfs.transform(data)
#data = fs_selector.fit_transform(data, target)
data_train2, data_test2, target_train2, target_test2 = train_test_split(data,target, test_size = 0.25, shuffle=True)
class_names=np.array(['0','1'])
from sklearn.ensemble import AdaBoostClassifier
from random import *
lg1=LogisticRegression(class_weight={0:0.5, 1:2}, C=0.1, max_iter=300, solver='newton-cg')
lg1.fit(data_train, target_train)
Pred_labels = lg1.predict(data_test)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels))
print(classification_report(target_test,Pred_labels))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels)
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels)
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
print(sqrt(mean_squared_error(target_test,Pred_labels.round())))
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round())) 
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [1 0]
# [[20040    30]
#  [   21   116]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20070
#            1       0.79      0.85      0.82       137
#
#     accuracy                           1.00     20207
#    macro avg       0.90      0.92      0.91     20207
# weighted avg       1.00      1.00      1.00     20207
#
# 0.8185184422083208
# No Skill PR AUC: 0.821
# Logistic ROC AUC 0.923
# SpearmanrResult(correlation=0.8189385322415085, pvalue=0.0)
# 0.0025238778641064976
# 0.0025238778641064976
# 0.050238211195329174
# 0.6251961201488221
# 0.6252255790863364
# 0.8189385322415087

# %% [markdown]
# # LInearSVC

# %%
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,LogisticRegression
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(47)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset_MM-SeqComb_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
target = OT_data['Y']
#fs_selector = VarianceThreshold(0.000019)
#data=sfs.transform(data)
#data = fs_selector.fit_transform(data, target)
data_train2, data_test2, target_train2, target_test2 = train_test_split(data,target, test_size = 0.25, shuffle=True)
class_names=np.array(['0','1'])
svc=LinearSVC(C=0.2, loss='squared_hinge', penalty='l2', dual=False, tol=0.0002, class_weight={0:0.173, 1:0.80})
svc.fit(data_train, target_train)
Pred_labels = svc.predict(data_test)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels))
print(classification_report(target_test,Pred_labels))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels)
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels)
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
print(sqrt(mean_squared_error(target_test,Pred_labels.round())))
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round())) 
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [1 0]
# [[20034    36]
#  [   24   113]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20070
#            1       0.76      0.82      0.79       137
#
#     accuracy                           1.00     20207
#    macro avg       0.88      0.91      0.89     20207
# weighted avg       1.00      1.00      1.00     20207
#
# 0.7887172259189708
# No Skill PR AUC: 0.792
# Logistic ROC AUC 0.912
# SpearmanrResult(correlation=0.7894223435784805, pvalue=0.0)
# 0.002969268075419409
# 0.002969268075419409
# 0.05449099077296548
# 0.5590542589986143
# 0.5591066304430841
# 0.7894223435784807

# %% [markdown]
# # AdaBoostClassifer

# %%
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,LogisticRegression
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(47)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset_MM-SeqComb_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
target = OT_data['Y']
#fs_selector = VarianceThreshold(0.000019)
#data=sfs.transform(data)
#data = fs_selector.fit_transform(data, target)
data_train2, data_test2, target_train2, target_test2 = train_test_split(data,target, test_size = 0.25, shuffle=True)
class_names=np.array(['0','1'])
from sklearn.ensemble import AdaBoostClassifier
from random import *
ada= AdaBoostClassifier(n_estimators=255, learning_rate=0.741, random_state=0)
ada.fit(data_train, target_train)
Pred_labels = ada.predict(data_test)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(target_test,Pred_labels))
print(classification_report(target_test,Pred_labels))
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(target_test,Pred_labels))
precision, recall, _ = precision_recall_curve(target_test,Pred_labels)
auc_score = auc(recall, precision)
print('No Skill PR AUC: %.3f' % auc_score)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(target_test,Pred_labels)
print('Logistic ROC AUC %.3f' % roc_auc)
from scipy.stats import spearmanr
print(spearmanr(target_test,Pred_labels.round()))
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(target_test,Pred_labels.round()))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(target_test,Pred_labels.round()))
from math import sqrt
print(sqrt(mean_squared_error(target_test,Pred_labels.round())))
from sklearn.metrics import r2_score
print(r2_score(target_test,Pred_labels.round()))
from sklearn.metrics import explained_variance_score
print(explained_variance_score(target_test,Pred_labels.round())) 
from sklearn.metrics import matthews_corrcoef
print(matthews_corrcoef(target_test,Pred_labels.round()))
# Out:
# off-target' :  [1 0]
# [[20062     8]
#  [   45    92]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20070
#            1       0.92      0.67      0.78       137
#
#     accuracy                           1.00     20207
#    macro avg       0.96      0.84      0.89     20207
# weighted avg       1.00      1.00      1.00     20207
#
# 0.7750844821101217
# No Skill PR AUC: 0.797
# Logistic ROC AUC 0.836
# SpearmanrResult(correlation=0.7848193972046549, pvalue=0.0)
# 0.002622853466620478
# 0.002622853466620478
# 0.05121380152478898
# 0.6104979287821093
# 0.6109958211951598
# 0.784819397204655

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
import matplotlib.pyplot as plt
from sklearn.metrics import plot_roc_curve
import matplotlib.font_manager as font_manager

#ax = plt.gca()
fig, ax = plt.subplots(figsize=(20, 20))

#plt.legend(["RandomFOrestClassifier (AP=0.89)", "LinearSVC (AP=0.89)", "LogistivRegression (Ap=0.89)", "DecisionTreeClassifer (Ap-0.69)", "AdaboostClassifier (Ap=0.90)", "MLPClassifier (Ap=0.87)"], prop={"size":25, "family":'Arial Rounded MT Bold'})

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xticks(font="Arial Rounded MT Bold", fontsize=50)
plt.xlabel('Predicted label', font="Arial Rounded MT Bold", fontsize=70)
plt.ylabel('True label', font="Arial Rounded MT Bold", fontsize=70)
plt.yticks(font="Arial Rounded MT Bold", fontsize=50)
scv1=plot_precision_recall_curve(mlp, data_test, target_test, linewidth = 6, ax=ax) 
scv2=plot_precision_recall_curve(clf, data_test1, target_test1, linewidth = 6, ax=ax)
scv3=plot_precision_recall_curve(clf2, data_test2, target_test2, linewidth = 6, ax=ax)

scv1.plot(ax=ax)
#ax.legend(["MLPClassifer (Ap=0.87)", "RandomForestClassifier(AP = 0.89)", "LinearSVC (AP = 0.89)", "LogisticRegrgession (AP = 0.89)", "DecisionTreeClassifier (AP = 0.69)", "AdaboostClassifier (AP = 0.87)"], prop={"size":50, "family":'Arial Rounded MT Bold'}, loc="lower left")
#plt.title('Normalized Confusion Matrix \n', font="Arial Rounded MT Bold", fontsize=18)
font = font_manager.FontProperties(family='Arial Rounded MT Bold', size=50)
#ax.legend(prop=font)
ax.legend(["SeqBasedClassifier (AP=0.87)", "MMEClassifier (AP = 0.87)", "CombClassifier (AP = 0.89)"], prop={"size":50, "family":'Arial Rounded MT Bold'}, loc="lower left")
#plt.title('Normalized Confusion Matrix \n', font="Arial Rounded MT Bold", fontsize=18)
#plt.show()
plt.tight_layout()
plt.savefig("D://PhD_related/manuscript_obj1/update_images/Precision-Recall_LbCpf1-saved2.png", dpi=1500)

# %%
from sklearn.metrics import roc_curve
from numpy import interp
import warnings  
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,LogisticRegression
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold, KFold
import matplotlib.font_manager as font_manager
import numpy as np
np.random.seed(235)
OT_data=pd.read_csv(r"D://PhD_related/obj1_MM/mismatch_energy_LbCpf1/LbCpf1_Dataset_MM-SeqComb_clean1.csv", index_col=[0], encoding="cp1252")
#df = pd.DataFrame(OT_data)
le = preprocessing.LabelEncoder()
print("off-target' : ",OT_data['Y'].unique())
OT_data['Y'] = le.fit_transform(OT_data['Y'])
cols = [col for col in OT_data.columns if col not in ['Y']]
data = OT_data[cols]
data=np.asarray(data)
target = OT_data['Y']
target=np.asarray(target)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=29)
i=0
f, axes = plt.subplots(figsize=(20,20))
'''axes[0].scatter(data[target==0,0], data[target==0,1], color='blue', s=2, label='y=0')
axes[0].scatter(data[target!=0,0], data[target!=0,1], color='red', s=2, label='y=1')
axes[0].set_xlabel('data[:,0]')
axes[0].set_ylabel('data[:,1]')
axes[0].legend(loc='lower left', fontsize='small')'''
y_real = []
y_proba = []
for train_index, val_index in skf.split(data, target): 
    i=i+1
    print("Train:", train_index, "Validation:", val_index) 
    data_train, data_test = data[train_index], data[val_index] 
    target_train, target_test = target[train_index], target[val_index]
    clf = clf = MLPClassifier(solver='adam', alpha=0.0002, activation= 'relu', hidden_layer_sizes=[10, 10, 12, 25, 12], learning_rate_init=0.001, random_state=13, tol=0.0000002, learning_rate='adaptive', beta_1=0.9, beta_2=0.71, epsilon=1e-23, n_iter_no_change=20, validation_fraction=0.25, verbose=False)
    clf.fit(data_train, target_train)
    pred_proba=clf.predict_proba(data_test)
    precision, recall, _ = precision_recall_curve(target_test, pred_proba[:,1])
    lab = 'Fold %d AUC=%.4f' % (i, auc(recall, precision))
    axes.step(recall, precision, label=lab, lw=6)
    y_real.append(target_test)
    y_proba.append(pred_proba[:,1])
y_real = np.concatenate(y_real)
y_proba = np.concatenate(y_proba)
precision, recall, _ = precision_recall_curve(y_real, y_proba)
lab = 'Overall AUC=%.4f' % (auc(recall, precision))
axes.step(recall, precision, label=lab, lw=6, color='black')
axes.set_xlabel('Recall')
axes.set_ylabel('Precision')
axes.legend(loc='lower left', fontsize='small')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xticks(font="Arial Rounded MT Bold", fontsize=50)
plt.xlabel('Predicted label', font="Arial Rounded MT Bold", fontsize=70)
plt.ylabel('True label', font="Arial Rounded MT Bold", fontsize=70)
plt.yticks(font="Arial Rounded MT Bold", fontsize=50)
f.tight_layout()
#f.savefig('result.png')
font = font_manager.FontProperties(family='Arial Rounded MT Bold', size=50)
#ax.legend(prop=font)
axes.legend(["Fold 1 AUC=0.8060", "Fold 2 AUC=0.8622", "Fold 3 AUC=0.8748", "Fold 4 AUC=0.8253", "Fold 5 AUC=0.7562", "Overall AUC=0.8118"], prop={"size":50, "family":'Arial Rounded MT Bold'}, loc="lower left")
#plt.title('Normalized Confusion Matrix \n', font="Arial Rounded MT Bold", fontsize=18)
#f.show()
plt.savefig("D://PhD_related/manuscript_obj1/update_images/5-foldCV_LbCpf1-saved.png", dpi=1500)
# Out:
# off-target' :  [1 0]
# Train: [    2     3     4 ... 80825 80826 80827] Validation: [    0     1    11 ... 80814 80818 80821]
# Train: [    0     1     2 ... 80825 80826 80827] Validation: [    5    12    13 ... 80812 80815 80816]
# Train: [    0     1     2 ... 80824 80825 80827] Validation: [    4     7    22 ... 80810 80820 80826]
# Train: [    0     1     2 ... 80821 80825 80826] Validation: [    3     6     8 ... 80823 80824 80827]
# Train: [    0     1     3 ... 80824 80826 80827] Validation: [    2     9    18 ... 80811 80819 80825]
